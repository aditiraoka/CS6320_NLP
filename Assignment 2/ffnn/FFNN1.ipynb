# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/finalDraft/ffnn/"
trainPath= "/content/drive/MyDrive/finalDraft/ffnn/training.json"
valPath = "/content/drive/MyDrive/finalDraft/ffnn/validation.json"
testPath = "/content/drive/MyDrive/finalDraft/ffnn/test.json"

# %%
# !python $path'ffnn.py' --hidden_dim 10 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# ========== Training for 10 epochs ==========
# Training started for epoch 1
#   0% 0/500 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# 100% 500/500 [00:11<00:00, 42.92it/s]
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.513
# Training time for this epoch: 11.66
# Training loss for this epoch: 0.7251972556114197
# **** Validation for 10 epochs ****
# Validation started for epoch 1
# 100% 50/50 [00:00<00:00, 141.07it/s]
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.55875
# Validation time for this epoch: 0.35
# Training started for epoch 2
# 100% 500/500 [00:11<00:00, 43.67it/s]
# Training completed for epoch 2
# Training accuracy for epoch 2: 0.5645
# ...

# %%
# !python $path'ffnn.py' --hidden_dim 15 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# ========== Training for 10 epochs ==========
# Training started for epoch 1
#   0% 0/500 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# 100% 500/500 [00:14<00:00, 34.51it/s]
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.52575
# Training time for this epoch: 14.5
# Training loss for this epoch: 0.7459861040115356
# **** Validation for 10 epochs ****
# Validation started for epoch 1
# 100% 50/50 [00:00<00:00, 93.60it/s]
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.545
# Validation time for this epoch: 0.53
# Training started for epoch 2
# 100% 500/500 [00:16<00:00, 31.02it/s]
# Training completed for epoch 2
# Training accuracy for epoch 2: 0.5775
# ...

# %%
# !python $path'ffnn.py' --hidden_dim 64 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# ========== Training for 10 epochs ==========
# Training started for epoch 1
#   0% 0/500 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# 100% 500/500 [01:19<00:00,  6.28it/s]
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.534625
# Training time for this epoch: 79.57
# Training loss for this epoch: 0.7223763465881348
# **** Validation for 10 epochs ****
# Validation started for epoch 1
# 100% 50/50 [00:01<00:00, 35.06it/s]
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.54375
# Validation time for this epoch: 1.43
# Training started for epoch 2
# 100% 500/500 [01:25<00:00,  5.83it/s]
# Training completed for epoch 2
# ...

# %%
# !python $path'ffnn.py' --hidden_dim 24 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# ========== Training for 10 epochs ==========
# Training started for epoch 1
#   0% 0/500 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# 100% 500/500 [00:22<00:00, 22.27it/s]
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.521375
# Training time for this epoch: 22.46
# Training loss for this epoch: 0.7211729288101196
# **** Validation for 10 epochs ****
# Validation started for epoch 1
# 100% 50/50 [00:00<00:00, 94.79it/s]
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.55375
# Validation time for this epoch: 0.53
# Training started for epoch 2
# 100% 500/500 [00:24<00:00, 20.29it/s]
# Training completed for epoch 2
# ...

# %%
# !python $path'ffnn.py' --hidden_dim 128 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# ========== Training for 10 epochs ==========
# Training started for epoch 1
#   0% 0/500 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py:1518: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self._call_impl(*args, **kwargs)
# 100% 500/500 [04:15<00:00,  1.96it/s]
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.530125
# Training time for this epoch: 255.53
# Training loss for this epoch: 0.7281283140182495
# **** Validation for 10 epochs ****
# Validation started for epoch 1
# 100% 50/50 [00:03<00:00, 15.68it/s]
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.5425
# Validation time for this epoch: 3.19
# Training started for epoch 2
# 100% 500/500 [04:24<00:00,  1.89it/s]
# Training completed for epoch 2
# ...

# %%
# !python $path'ffnn.py' --hidden_dim 51 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
