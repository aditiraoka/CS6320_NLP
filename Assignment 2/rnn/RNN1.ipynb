# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/finalDraft/rnn/"
trainPath= "/content/drive/MyDrive/finalDraft/rnn/Data_Embedding/training.json"
valPath = "/content/drive/MyDrive/finalDraft/rnn/Data_Embedding/validation.json"
testPath = "//content/drive/MyDrive/finalDraft/rnn/Data_Embedding/test.json"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !python $path'rnn.py' --hidden_dim 10 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# Training started for epoch 1
# 100% 1000/1000 [03:17<00:00,  5.07it/s]
# tensor(1.5796)
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.2565
# Validation started for epoch 1
# 100% 800/800 [00:04<00:00, 183.54it/s]
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.315
# Training started for epoch 2
# 100% 1000/1000 [03:18<00:00,  5.03it/s]
# tensor(1.5795)
# Training completed for epoch 2
# Training accuracy for epoch 2: 0.26425
# Validation started for epoch 2
# 100% 800/800 [00:03<00:00, 215.20it/s]
# Validation completed for epoch 2
# Validation accuracy for epoch 2: 0.3825
# Training started for epoch 3
# 100% 1000/1000 [03:18<00:00,  5.03it/s]
# tensor(1.5804)
# Training completed for epoch 3
# Training accuracy for epoch 3: 0.2614375
# Validation started for epoch 3
# 100% 800/800 [00:03<00:00, 204.04it/s]
# Validation completed for epoch 3
# ...

# %%
# !python $path'rnn.py' --hidden_dim 15 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# Training started for epoch 1
# 100% 1000/1000 [03:19<00:00,  5.01it/s]
# tensor(1.5908)
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.2536875
# Validation started for epoch 1
# 100% 800/800 [00:03<00:00, 234.32it/s]
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.3175
# Training started for epoch 2
# 100% 1000/1000 [03:19<00:00,  5.01it/s]
# tensor(1.5995)
# Training completed for epoch 2
# Training accuracy for epoch 2: 0.2514375
# Validation started for epoch 2
# 100% 800/800 [00:03<00:00, 204.83it/s]
# Validation completed for epoch 2
# Validation accuracy for epoch 2: 0.43
# Training started for epoch 3
# 100% 1000/1000 [03:18<00:00,  5.04it/s]
# tensor(1.5903)
# Training completed for epoch 3
# Training accuracy for epoch 3: 0.2514375
# Validation started for epoch 3
# 100% 800/800 [00:04<00:00, 164.53it/s]
# Validation completed for epoch 3
# ...

# %%
# !python $path'rnn.py' --hidden_dim 64 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# Training started for epoch 1
# 100% 1000/1000 [03:51<00:00,  4.32it/s]
# tensor(1.6673)
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.2154375
# Validation started for epoch 1
# 100% 800/800 [00:03<00:00, 200.14it/s]
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.365
# Training started for epoch 2
# 100% 1000/1000 [03:51<00:00,  4.33it/s]
# tensor(1.6645)
# Training completed for epoch 2
# Training accuracy for epoch 2: 0.229125
# Validation started for epoch 2
# 100% 800/800 [00:03<00:00, 210.57it/s]
# Validation completed for epoch 2
# Validation accuracy for epoch 2: 0.0375
#
# Training done to avoid overfitting!
# Best validation accuracy is: 0.365
# ========== Test data ==========
# 100% 800/800 [00:01<00:00, 459.69it/s]
# Test Accuracy for the model: 0.38875

# %%
# !python $path'rnn.py' --hidden_dim 64 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# Training started for epoch 1
# 100% 1000/1000 [03:54<00:00,  4.26it/s]
# tensor(1.6551)
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.2280625
# Validation started for epoch 1
# 100% 800/800 [00:03<00:00, 214.53it/s]
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.15875
# Training started for epoch 2
# 100% 1000/1000 [03:57<00:00,  4.20it/s]
# tensor(1.6444)
# Training completed for epoch 2
# Training accuracy for epoch 2: 0.244875
# Validation started for epoch 2
# 100% 800/800 [00:04<00:00, 171.60it/s]
# Validation completed for epoch 2
# Validation accuracy for epoch 2: 0.19
# Training started for epoch 3
# 100% 1000/1000 [03:56<00:00,  4.24it/s]
# tensor(1.6508)
# Training completed for epoch 3
# Training accuracy for epoch 3: 0.233875
# Validation started for epoch 3
# 100% 800/800 [00:03<00:00, 210.87it/s]
# Validation completed for epoch 3
# ...

# %%
# !python $path'rnn.py' --hidden_dim 24 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# Training started for epoch 1
# 100% 1000/1000 [03:28<00:00,  4.79it/s]
# tensor(1.6051)
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.2488125
# Validation started for epoch 1
# 100% 800/800 [00:03<00:00, 231.61it/s]
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.13125
# Training started for epoch 2
# 100% 1000/1000 [03:24<00:00,  4.89it/s]
# tensor(1.5960)
# Training completed for epoch 2
# Training accuracy for epoch 2: 0.2530625
# Validation started for epoch 2
# 100% 800/800 [00:04<00:00, 171.35it/s]
# Validation completed for epoch 2
# Validation accuracy for epoch 2: 0.23375
# Training started for epoch 3
# 100% 1000/1000 [03:26<00:00,  4.83it/s]
# tensor(1.5881)
# Training completed for epoch 3
# Training accuracy for epoch 3: 0.26225
# Validation started for epoch 3
# 100% 800/800 [00:03<00:00, 231.69it/s]
# Validation completed for epoch 3
# ...

# %%
# !python $path'rnn.py' --hidden_dim 128 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# Training started for epoch 1
# 100% 1000/1000 [04:52<00:00,  3.42it/s]
# tensor(1.7339)
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.2076875
# Validation started for epoch 1
# 100% 800/800 [00:04<00:00, 193.42it/s]
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.0025
# Training started for epoch 2
# 100% 1000/1000 [04:31<00:00,  3.69it/s]
# tensor(1.7176)
# Training completed for epoch 2
# Training accuracy for epoch 2: 0.2124375
# Validation started for epoch 2
# 100% 800/800 [00:03<00:00, 201.51it/s]
# Validation completed for epoch 2
# Validation accuracy for epoch 2: 0.26125
# Training started for epoch 3
# 100% 1000/1000 [04:21<00:00,  3.82it/s]
# tensor(1.7273)
# Training completed for epoch 3
# Training accuracy for epoch 3: 0.2145
# Validation started for epoch 3
# 100% 800/800 [00:04<00:00, 182.41it/s]
# Validation completed for epoch 3
# ...

# %%
# !python $path'rnn.py' --hidden_dim 51 --epochs 10 --train_data $trainPath --val_data $valPath --test_data $testPath --out_path $path
# Out:
# ========== Loading data ==========
# ========== Vectorizing data ==========
# Training started for epoch 1
# 100% 1000/1000 [03:48<00:00,  4.38it/s]
# tensor(1.6457)
# Training completed for epoch 1
# Training accuracy for epoch 1: 0.2305
# Validation started for epoch 1
# 100% 800/800 [00:04<00:00, 199.79it/s]
# Validation completed for epoch 1
# Validation accuracy for epoch 1: 0.3925
# Training started for epoch 2
# 100% 1000/1000 [03:52<00:00,  4.30it/s]
# tensor(1.6277)
# Training completed for epoch 2
# Training accuracy for epoch 2: 0.24475
# Validation started for epoch 2
# 100% 800/800 [00:04<00:00, 199.78it/s]
# Validation completed for epoch 2
# Validation accuracy for epoch 2: 0.13375
#
# Training done to avoid overfitting!
# Best validation accuracy is: 0.3925
# ========== Test data ==========
# 100% 800/800 [00:01<00:00, 406.12it/s]
# Test Accuracy for the model: 0.3325
